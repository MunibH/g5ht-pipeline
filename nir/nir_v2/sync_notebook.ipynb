# %% [markdown]
# `conda activate imgpro`

# %%
import h5py
import numpy as np
import os
import matplotlib.pyplot as plt
import sys
import importlib
# _ = importlib.reload(sys.modules['sync'])
# set default matplotlib parameters for better aesthetics
plt.rcParams['figure.figsize'] = (10, 6)
# fontsize
plt.rcParams['axes.titlesize'] = 12
plt.rcParams['axes.labelsize'] = 16
plt.rcParams['xtick.labelsize'] = 16
plt.rcParams['ytick.labelsize'] = 16
plt.rcParams['legend.fontsize'] = 13
plt.rcParams['lines.linewidth'] = 2

# ============================================================
# SET YOUR DATA PATH HERE
# ============================================================
# PTH = r'D:\DATA\g5ht-free\20251223'
# FN = 'date-20251223_strain-ISg5HT_condition-starvedpatch_worm005'  # without .h5 extension

# PTH = r'D:\DATA\g5ht-free\20260220'
# FN = 'date-20260220_strain-ISg5HT-NSM-TeTx_condition-starvedpatch_worm008'  # without .h5 extension

PTH = r'D:\DATA\g5ht-free\20251121'
FN = 'date-20251121_strain-ISg5HT_condition-fedpatch_worm001'

h5_path = os.path.join(PTH, FN + '.h5')

# Number of z-slices per confocal volume
N_STACK = 41
NIDAQ_SAMPLE_RATE_AI = 5000.0 # Hz
CONTROL_NIR_FPS = 40.0
SAVE_NIR_FPS = 20.0

print(f"Looking for: {h5_path}")
print(f"File exists: {os.path.exists(h5_path)}")
# Out:
# Looking for: D:\DATA\g5ht-free\20251121\date-20251121_strain-ISg5HT_condition-fedpatch_worm001.h5
# File exists: True

# %%
from sync import sync_timing_from_h5

confocal_to_nir, nir_to_confocal, timing_stack, timing_nir, timing_piezo = sync_timing_from_h5(h5_path)

# confocal_to_nir is a list of np arrays, each of which contains the nir frames associated with each confocal stack
# nir_to_confocal is a numpy array, one entry per nir frame, indicating which confocal stack each nir frame maps to

# %%
plt.figure(figsize=(12, 4))
plt.plot(nir_to_confocal, '.', markersize=1)
plt.show()
