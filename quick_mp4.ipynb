# %%
from nd2reader import ND2Reader
import tifffile as tif
import numpy as np
import os.path as osp
import os
import imageio
import tqdm
import re
from utils import parse_datasets, get_output_dir, make_mip_rgb

# %%
noise_path = '/home/munib/code/g5ht-pipeline/noise/noise_111125.tif'
noise_tif = tif.imread(noise_path).astype(np.float32)
datasets_path = 'datasets.txt'
fps = 5 / 0.533
Z = 41
C = 2

# %%
def get_stack(f, index, noise, n_zplanes, n_channels, trim=2):
    """Read a z-stack at the given time index, subtract noise, and trim."""
    height, width = f.metadata['height'], f.metadata['width']
    stack = np.zeros((n_zplanes, n_channels, height, width), np.float32)
    for i, j in enumerate(range(n_zplanes * index, n_zplanes * (index + 1))):
        for c in range(n_channels):
            stack[i, c] = f.get_frame_2D(c, j)
    denoised = np.clip(stack - noise, 0, 4095)
    return denoised[trim:]

# %%
nd2_paths = parse_datasets(datasets_path, section='UNPROCESSED')


for nd2_path in tqdm.tqdm(nd2_paths, desc='Files'):
    if not osp.exists(nd2_path):
        print(f'Skipping (not found): {nd2_path}')
        continue
    print('Making mp4 for:', nd2_path)

    output_dir = get_output_dir(nd2_path)
    # print(output_dir)
    mp4_path = osp.join(output_dir, 'unprocessed_confocal_video.mp4')
    if osp.exists(mp4_path):
        continue

    with ND2Reader(nd2_path) as f:
        # n_zplanes = f.sizes.get('z', 1)
        # print(f.metadata.keys())
        H, W = f.metadata['height'], f.metadata['width']
        nFrames = f.metadata['num_frames']
        nVolumes = nFrames // Z
    
        with imageio.get_writer(mp4_path, fps=fps) as mp4:
            for i in tqdm.tqdm(range(nVolumes), leave=False):
                stack = get_stack(f, i, noise_tif, Z, C)
                mp4.append_data(make_mip_rgb(stack))
# Out:
# Files:   0%|          | 0/12 [00:00<?, ?it/s]
# Making mp4 for: /store1/shared/g5ht/data/20260112/date-20260112_strain-ISg5HT_condition-fedpatch_worm001.nd2
# Files:   8%|▊         | 1/12 [08:01<1:28:15, 481.42s/it]
# Making mp4 for: /store1/shared/g5ht/data/20260112/date-20260112_strain-ISg5HT_condition-fedpatch_worm002.nd2
# Files:  17%|█▋        | 2/12 [16:29<1:22:52, 497.24s/it]
# Making mp4 for: /store1/shared/g5ht/data/20260113/date-20260113_strain-ISg5HT-ADF-TeTx_condition-starvedpatch_worm001.nd2
# Files:  25%|██▌       | 3/12 [31:49<1:43:32, 690.28s/it]
# Making mp4 for: /store1/shared/g5ht/data/20260113/date-20260113_strain-ISg5HT-ADF-TeTx_condition-starvedpatch_worm005.nd2
# Files:  33%|███▎      | 4/12 [51:51<1:58:57, 892.23s/it]
# Skipping (not found): /store1/shared/g5ht/data/20260120/date-20260114_strain-ISg5HT_condition-starvedpatch_worm001.nd2
# Making mp4 for: /store1/shared/g5ht/data/20260120/date-20260120_strain-ISg5HT_condition-starvedpatch_worm001.nd2
# ...
