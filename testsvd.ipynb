# %%
import os
import sys
import glob
import numpy as np
import tifffile

# %%
PTH = r'C:\Users\munib\POSTDOC\DATA\g5-HT-free\022025_eft_41z_starved_worm002\registered'
contents = glob.glob(os.path.join(PTH,'*.tif'))


im = np.zeros((117,2,200,500,1200))
for i,tif in enumerate(contents):
    im[:,:,:,:,i] = tifffile.imread(tif)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[4], line 5
#       1 PTH = r'C:\Users\munib\POSTDOC\DATA\g5-HT-free\022025_eft_41z_starved_worm002\registered'
#       2 contents = glob.glob(os.path.join(PTH,'*.tif'))
# ----> 5 im = np.zeros((117,2,200,500,1200))
#       6 for i,tif in enumerate(contents):
#       7     im[:,:,:,:,i] = tifffile.imread(tif)
#
# MemoryError: Unable to allocate 209. GiB for an array with shape (117, 2, 200, 500, 1200) and data type float64

# %%
im.shape
# Out:
# (117, 2, 200, 500)
