# %%
import os
import sys
import glob
import numpy as np
import tifffile

# %%
PTH = r'C:\Users\munib\POSTDOC\DATA\g5-HT-free\022025_eft_41z_starved_worm002\registered'
contents = glob.glob(os.path.join(PTH,'*.tif'))


# im = 
for i in contents:
    im = tifffile.imread(i) # ()
    break

# %%
im.shape
# Out:
# (117, 2, 200, 500)
